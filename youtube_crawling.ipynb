# %%
from __future__ import print_function

import io
import json
import os
import sys
import time

import argparse
import lxml.html
import requests
from lxml.cssselect import CSSSelector
import datetime
 
now = datetime.datetime.now()

# %%
def download_comments(youtube_id, sleep=.1):
    if 'liveStreamability' in requests.get(YOUTUBE_VIDEO_URL.format(youtube_id=youtube_id)).text:
        print('Live stream detected! Not all comments may be downloaded.')
        return download_comments_new_api(youtube_id, sleep)
    return download_comments_old_api(youtube_id, sleep)

# %%
def download_comments_new_api(youtube_id, sleep=1):
    # Use the new youtube API to download some comments
    session = requests.Session()
    session.headers['User-Agent'] = USER_AGENT

    response = session.get(YOUTUBE_VIDEO_URL.format(youtube_id=youtube_id))
    html = response.text
    session_token = find_value(html, 'XSRF_TOKEN', 3)

    data = json.loads(find_value(html, 'window["ytInitialData"] = ', 0, '\n').rstrip(';'))
    ncd = next(search_dict(data, 'nextContinuationData'))
    continuations = [(ncd['continuation'], ncd['clickTrackingParams'])]

    while continuations:
        continuation, itct = continuations.pop()
        response = ajax_request(session, YOUTUBE_COMMENTS_AJAX_URL_NEW,
                                params={'action_get_comments': 1,
                                        'pbj': 1,
                                        'ctoken': continuation,
                                        'continuation': continuation,
                                        'itct': itct},
                                data={'session_token': session_token},
                                headers={'X-YouTube-Client-Name': '1',
                                         'X-YouTube-Client-Version': '2.20200207.03.01'})

        if not response:
            break
        if list(search_dict(response, 'externalErrorMessage')):
            raise RuntimeError('Error returned from server: ' + next(search_dict(response, 'externalErrorMessage')))

        # Ordering matters. The newest continuations should go first.
        continuations = [(ncd['continuation'], ncd['clickTrackingParams'])
                         for ncd in search_dict(response, 'nextContinuationData')] + continuations

        for comment in search_dict(response, 'commentRenderer'):
            yield {'cid': comment['commentId'],
                   'text': ''.join([c['text'] for c in comment['contentText']['runs']]),
                   'time': comment['publishedTimeText']['runs'][0]['text'],
                   'author': comment.get('authorText', {}).get('simpleText', '')}

        time.sleep(sleep)

# %%
def download_comments_old_api(youtube_id, sleep=1):
    # Use the old youtube API to download all comments (does not work for live streams)
    session = requests.Session()
    session.headers['User-Agent'] = USER_AGENT
    
    # Get Youtube page with initial comments
    response = session.get(YOUTUBE_VIDEO_URL.format(youtube_id=youtube_id))
    html = response.text

    reply_cids = extract_reply_cids(html)

    ret_cids = []
    for comment in extract_comments(html):
        ret_cids.append(comment['cid'])
        yield comment

    page_token = find_value(html, 'data-token')
    session_token = find_value(html, 'XSRF_TOKEN', 3)

    first_iteration = True

    # Get remaining comments (the same as pressing the 'Show more' button)
    while page_token:
        data = {'video_id': youtube_id,
                'session_token': session_token}

        params = {'action_load_comments': 1,
                  'order_by_time': True,
                  'filter': youtube_id}

        if first_iteration:
            params['order_menu'] = True
        else:
            data['page_token'] = page_token

        response = ajax_request(session, YOUTUBE_COMMENTS_AJAX_URL_OLD, params, data)
        if not response:
            break

        page_token, html = response.get('page_token', None), response['html_content']
        
        reply_cids += extract_reply_cids(html)
        for comment in extract_comments(html):
            if comment['cid'] not in ret_cids:
                ret_cids.append(comment['cid'])
                yield comment

        first_iteration = False
        time.sleep(sleep)

    # Get replies (the same as pressing the 'View all X replies' link)
    for cid in reply_cids:
        data = {'comment_id': cid,
                'video_id': youtube_id,
                'can_reply': 1,
                'session_token': session_token}

        params = {'action_load_replies': 1,
                  'order_by_time': True,
                  'filter': youtube_id,
                  'tab': 'inbox'}

        response = ajax_request(session, YOUTUBE_COMMENTS_AJAX_URL_OLD, params, data)
        if not response:
            break

        html = response['html_content']

        for comment in extract_comments(html):
            if comment['cid'] not in ret_cids:
                ret_cids.append(comment['cid'])
                yield comment
        time.sleep(sleep)

# %%
def extract_reply_cids(html):
    tree = lxml.html.fromstring(html)
    sel = CSSSelector('.comment-replies-header > .load-comments')
    return [i.get('data-cid') for i in sel(tree)]

# %%
def extract_comments(html):
    tree = lxml.html.fromstring(html)
    item_sel = CSSSelector('.comment-item')
    text_sel = CSSSelector('.comment-text-content')
    time_sel = CSSSelector('.time')
    author_sel = CSSSelector('.user-name')

    for item in item_sel(tree):
        yield {'cid': item.get('data-cid'),
               'text': text_sel(item)[0].text_content(),
               'time': time_sel(item)[0].text_content().strip(),
               'author': author_sel(item)[0].text_content()}

# %%
def find_value(html, key, num_chars=2, separator='"'):
    pos_begin = html.find(key) + len(key) + num_chars
    pos_end = html.find(separator, pos_begin)
    return html[pos_begin: pos_end]

# %%
def ajax_request(session, url, params=None, data=None, headers=None, retries=5, sleep=20):
    for _ in range(retries):
        response = session.post(url, params=params, data=data, headers=headers)
        if response.status_code == 200:
            return response.json()
        if response.status_code in [403, 413]:
            return {}
        else:
            time.sleep(sleep)

# %%
YOUTUBE_VIDEO_URL = 'https://www.youtube.com/watch?v={youtube_id}'
YOUTUBE_COMMENTS_AJAX_URL_OLD = 'https://www.youtube.com/comment_ajax'
YOUTUBE_COMMENTS_AJAX_URL_NEW = 'https://www.youtube.com/comment_service_ajax'

USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.130 Safari/537.36'


output = './test.csv'
def comment_main(youtube_id):    
    youtube_id = youtube_id    
    comment_list = []

    limit = 100
    count = 0
    with io.open(output, 'w', encoding='utf8') as fp:
        sys.stdout.write('Downloaded %d comment(s)\r' % count)
        sys.stdout.flush()
        for comment in download_comments(youtube_id):
            comment_json = json.dumps(comment, ensure_ascii=False)
            print(comment_json.decode('utf-8') if isinstance(comment_json, bytes) else comment_json, file=fp)
            count += 1
            comment_list.append(comment_json)
            sys.stdout.write('Downloaded %d comment(s)\r' % count)
            sys.stdout.flush()
            if limit and count >= limit:
                break
    print('\nDone!')
    return comment_list

# %%
result = comment_main('xOHrzDykafQ')
# Out:
# Downloaded 100 comment(s)
# Done!

# %%
result
# Out:
# ['{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg", "text": "현재 머슬레인 상황..\\nhttps://www.wadiz.kr/web/campaign/detail/qa/58125", "time": "4일 전", "author": "사망여우TV"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rMcGdBOm1", "text": "참교육", "time": "4일 전", "author": "안녕."}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rOWMAhWiy", "text": "후기 평가 1.1 클라스 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ", "time": "4일 전", "author": "Danbi 23"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rPdlporQA", "text": "시즌포는 TEZEWA의 대한민국 공식유통사이며, 머슬레인은 TEZEWA의 설계를 바탕으로 시즌포에서 기획, 디자인, 개발한 독자적인 제품으로 한국시장에 맞춰 개발 및 업그레이드하여\xa0시즌포의 요구기준에 따라 TEZEWA의 중국 생산공장에서 생산되는 OEM제품입니다.\xa0머슬레인과 유사한 제품이 해외 사이트 혹은 직구 등의 경로로 유통될 수 있으나 소재 및 성능, 가격, 구성품, 패키지 등 상당한 차이가 있음을 공유드립니다.\\n\\n이 십새끼들은 독자적이란 말의 뜻을 못 알아처먹나?", "time": "4일 전", "author": "콩구"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rPr_POA4e", "text": "엄청나네요.", "time": "4일 전", "author": "무서운곰"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rPywOhTk7", "text": "싫어요는 뭐지", "time": "4일 전", "author": "거센남자"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rRr5FM75k", "text": "민병대 여러분!!!! 일어납시다!!!!", "time": "4일 전", "author": "레떠 LETTE"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rT-9HIG_n", "text": "0", "time": "4일 전", "author": "Matthew Yim"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rU7Ske6-k", "text": "역시  와디즈 담당 일진 ㄷㄷㄷ", "time": "4일 전", "author": "Jeeho Hong"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rUJL3tJeX", "text": "3:50 와 개충격 ;;;", "time": "4일 전", "author": "오월owal"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rUm4dwJYq", "text": "와디즈를 더 깨부셔 주시길 바랍니다!! 저런 사기 듀오는 한번 혼나봐야됩니다!! 사망여우님을 믿습니다!!", "time": "4일 전", "author": "윤현기"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rWCpNWWFP", "text": "@거센남자 직원이겠죠?", "time": "4일 전", "author": "김수정"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rYHUcfDbB", "text": "첨에 사진 보고 국산 제품인데 영어로??? 근데 여자 사진....아 개소름....그냥 자신들이 우리 사기 쳤어요하고 광고하고 있네.....정말 이제는 와디즈는 믿고 걸러야.....되는데....분명 양심적이고 펀딩이 꼭 필요한 참기업도 있을텐데....이러면 그런 기업도 와디즈에 펀딩했다는 이유만으로 피해를 입을까 걱정되네요. 저도 몇 년안에 사업을 해서 제품을 만들어 펀딩을 할려고 하는데....무서워서 펀딩 못하겠네요.....", "time": "4일 전", "author": "고돈홍"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98r_-8LOXKp", "text": "아니 개돼지색히들 왜 와디즈에서 쇼핑을 쳐하냐고요 ㅋㅋㅋㅋ 아니 시바 ㅋㅋㅋ 도대체 그런 머리로 일이나 재대로 할랑가? 더군다나 사망여우 님이 친절하게 알려줘도 구입하네? ㅋㅋㅋㅋㅋ", "time": "4일 전", "author": "나무딸기"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98raBHwWkSP", "text": "http://it.chosun.com/site/data/html_dir/2020/05/19/2020051904051.html ㅋㅋㅋㅋㅋ", "time": "4일 전", "author": "김원준"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98raw9N9uZ4", "text": "@Danbi 23 ㅇㅈ", "time": "4일 전", "author": "차칸사람"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98raz8t1hzH", "text": "와디즈 계속 쌍욕해주시기 바랍니다", "time": "4일 전", "author": "차칸사람"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98reTSCAvWI", "text": "https://www.wadiz.kr/web/campaign/detail/64088 지금 와디즈에 비슷한 컨셉의 제품이 펀딩 중인데....사람들이 비슷한 종류이것만 보고 바디보스 짝퉁아니냐는 댓글이 많네요.....딱봐도 아닌데....와디즈가 잘 못되고 비양심 업체가 많아도 그냥 비슷한 종류니깐 일단 까고 보는 그런 모습은 좀 아닌것 같아요....", "time": "3일 전", "author": "고돈홍"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rgz66oxh_", "text": "@나무딸기 ? 그사람들은 사망여우를 모르는 사람들이에요.", "time": "3일 전(수정됨)", "author": "`늘조롱이`"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98riZi6SP_j", "text": "이정도면 와디즈에서 사는애들도 문제있다고 본다", "time": "3일 전", "author": "이쿼카"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rizeOqKHf", "text": "그렇게 사람들이 테제와인지 뭐시긴지 네이버 평보면 as 가관이라고 적어놨는데 알고도 산 사람들은 정말 할말이 없고 사놓고 안보고 모른 사람들은 정말 불쌍할 뿐..", "time": "3일 전", "author": "Elle Yoo"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rlAgCB571", "text": "이제는 지상공중파 매체에 제보를 해서 큰바람으로 흔들어야 바뀌지않을까 생각이드네요,, 여우님이 인터뷰로 정의구현하는 모습이 보고싶네요,,", "time": "3일 전", "author": "하하핫"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rnHlHuSfR", "text": "한여름  독한  시골모기집단  같네요..\\n\\n약을  뿌려도,  잡아도,,  열감지만  되면 달라드는..  \\n\\n죽더리도  피한번  빨고 싶은..", "time": "3일 전", "author": "이실장73"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rnhu0k1Ub", "text": "사망여우님의 영상. 언제나 잘 보고 있습니다.", "time": "3일 전", "author": "주동광"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98romycf0Vr", "text": "이제는 짭디즈라 불러야겠네", "time": "3일 전", "author": "영양호두과자"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rqsq1-s-k", "text": "@콩구 독자적인이 아니라 독재적인", "time": "3일 전", "author": "프리독"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98rrdHGYwz5", "text": "@거센남자 머슬레인&와디즈 관계자...", "time": "3일 전", "author": "HOGOON GARAGE"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98s-GsxN2mh", "text": "@Jeeho Hong 착한 일진", "time": "3일 전", "author": "신념e"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98s-idUWWGO", "text": "이 나라가 올바르게 돌아가길 바라는 마음이 조금이라도 있다면 구독 눌러주세요 100만 유튜버 만들어서 사망여우 혼내줍시다", "time": "3일 전", "author": "신념e"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98s05N5c9YH", "text": "@거센남자 와디즈 직원일듯 ㅋㅋ", "time": "3일 전", "author": "아린플레이저"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98sCIqK951C", "text": "와디즈의 방관 얼마나 갈까?? 시기가 안좋은데 조심하시길 ... 그리고 유튜브에 광고좀 그만하세요 보기싫은데 그만보기 안되대", "time": "3일 전", "author": "김영우"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98sHEPMRxga", "text": "덕분에 좋은제품 알게돼서 샀습니다ㅋㅋ 바디보스 제품 튼튼하고 좋네요", "time": "3일 전(수정됨)", "author": "JH Seok"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98sV1cR5dok", "text": "https://www.instagram.com/p/B9Gh1GEnawT/?igshid=16umewg1ri4p1 인스타그램에도 홍보하던데..", "time": "3일 전", "author": "김광"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98sdeF-PYha", "text": "응원합니다!!!", "time": "3일 전", "author": "김지영"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98seK3cwMU4", "text": "사망여우님 \\" 링티\\" 한번 털어주시면 안되나요... 아무리봐도 포카리파우더를 비싸게 파는 격 같아요... 성분을 아무리봐도 그냥  포카리이고 나르튬도 더 높아 보이는데.... 피로회복에 너무 탁월할거처럼 호도하는거같아요.  바우젠 전해수기 같은 느낌입니다.", "time": "3일 전", "author": "꼬마태양"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98sg8MTiXbR", "text": "이정도면 와디즈는 사기업체를 키우는거 아닐까?\\n이정도면 와디즈는 폐쇄를 해야 하지 않을까?\\n국민을 속이고, 대한민국 국격을 떨어뜨리는 행위를 하는 와디즈는 쓰레기!!\\n\\"와디즈는 쓰레기!\\"\\n\\"와디즈는 쓰레기!\\"\\n\\n진짜 너무나 화가난다.", "time": "3일 전", "author": "Kwang Seok Ryu"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98sgbQiaoiQ", "text": "한국 최고의 개망신 와디바바.\\n아~~나도 와디즈에서 사기나치고 돈좀 벌어볼까?", "time": "3일 전", "author": "긴돈혁"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98tobdR9aqq", "text": "제 지인이 이거펀딩이후에 영상보고 환불요청하니까 펀딩끝났다고 취소도안되고 물건배송받아야한다고 강매했다더라구여 그 구데기 집에 그냥 모셔둿다 하네요", "time": "3일 전", "author": "비싼올리브"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98uC9cmqv8X", "text": "우리도 중국기업 욕할 처지가 아니였구나ㅠㅠ", "time": "3일 전", "author": "youngil lee"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98uzwkoVtL4", "text": "\\"They are Chinese\\"", "time": "2일 전", "author": "이주효"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98v4yrMFxUp", "text": "와디즈 쓸데없는 회사죠. 저도 얼마전에 피부기기 구매하고 판매자와 의사소통시 그들의 말도안되는 행태에 소비자고발을 할까 하다 와디즈 에 먼저 그 행태를 얘기했죠. 결론이요? ㅋㅋㅋㅋㅋㅋ 웃프네요 그저.", "time": "2일 전", "author": "HW Lee"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98vUuwkpnxN", "text": "펀딩금액중 일정금액을 와디즈가 수작부리는건 아닐까?\\n와디즈가 법적대응 운운하는것 보면 펀딩금액 부풀리기에 동조하는것이 아닐까?  라는 합리적 의심이 드는데???", "time": "2일 전", "author": "Kwang Seok Ryu"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98vZPuXXpiy", "text": "걸린거 아니면 와디즈 또 입꾹닫했겠지", "time": "2일 전", "author": "Aiden"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98vZk8NCHAq", "text": "지금보니까 환불 신청 받고 있네요... 사망여우님의 노력이 빛을 발하네요!!", "time": "2일 전", "author": "winter7718"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98vigZ4T2Bn", "text": "감사합니다..", "time": "2일 전", "author": "sagaciousid"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98xolRUTrIF", "text": "사기집단이네. 고소못하나요", "time": "1일 전", "author": "Yoon KIM"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98yx2dC5fgq", "text": "가장 최근 댓글보세요 가관이네\\n\\"짝퉁이던 아니던 제품만 좋으면 된거아니냐\\"\\nㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ", "time": "1일 전", "author": "조조샤넬"}',
#  '{"cid": "Ugy0KR5xd1kFg4Zo7KV4AaABAg.98rMN8o1PHD98yxM7VkOZL", "text": "조조샤넬 관계자인가보네요 ㅎㅎㅎ", "time": "1일 전", "author": "Yoon KIM"}',
#  '{"cid": "Ugy1j77Kh6C8XYpHFX14AaABAg", "text": "유튜브에서 프리미엄 회원에게 한달 채널멤버십을 제공하길래 사망여우님 채널에 구독했습니다\\n사망여우님의 활동을 응원합니다", "time": "11분 전", "author": "late at night"}',
#  '{"cid": "Ugwf6qmVElQIApRZLgV4AaABAg", "text": "돈줬겠지", "time": "41분 전", "author": "박천영"}',
#  '{"cid": "Ugwq29xsajkZYRRE5qN4AaABAg", "text": "광고 마음껏 넣어요 계속 나갔다 와서 님 수익창출 해드릴테니", "time": "2시간 전", "author": "MissionE _korea"}',
#  '{"cid": "UgwHGnxYdmCQciAw5QF4AaABAg", "text": "와디즈도 병ㅅ 줫같은 개 씹새들... 아니 도대체 와디즈를 왜 자꾸 도와주는 호구 새끼들은 뭐지? 국민 재난지원금으로 도와주나? 니들이 중국인이냐....", "time": "3시간 전(수정됨)", "author": "서영감🍌"}',
#  '{"cid": "UgyNc1JoHWoT8g4SPuJ4AaABAg", "text": "와디즈 전문 저격유튜버", "time": "7시간 전", "author": "kr gy"}',
#  '{"cid": "UgyV2W6Qbhai9J5QS9R4AaABAg", "text": "특허청에서 제어가 안되는건가요?\\n제품의 저작권 이런거 짱퉁이라 안걸리나요? 흠. . .", "time": "7시간 전", "author": "Mr. 용용e"}',
#  '{"cid": "UgzJPQC5rLTw9ZSFhLt4AaABAg", "text": "와디즈 그냥 나두 탈퇴해야겠다...답없네", "time": "8시간 전", "author": "유시민"}',
#  '{"cid": "Ugwx45B1KEUclJUNre94AaABAg", "text": "와디즈에서 넥스트 아이엔티 라는 업체가 픽디자인 테크파우치 짭퉁을 팔고 있네요.\\n펀딩 마감 15일 남아있는데 하아... 참 양심이라고는 없는건가.\\n넥스트 아이엔티: https://www.wadiz.kr/web/campaign/detail/qa/66374\\n픽디자인 테크 파우치: https://www.peakdesign.com/products/tech-pouch/", "time": "9시간 전", "author": "Dan Park"}',
#  '{"cid": "UgxoDfZfzppNwjhtZ2V4AaABAg", "text": "응 위대한 한국", "time": "9시간 전", "author": "용용"}',
#  '{"cid": "UgxgRmgsE4ojXwakz-54AaABAg", "text": "와디즈에서 사망여우님 사기 감별하는 담당 직원으로 스카웃하는게 낫지않나? ㅋㅋㅋㅋ", "time": "9시간 전", "author": "업라이트upright"}',
#  '{"cid": "Ugx4-IZ1gPOdePN1Ujp4AaABAg", "text": "이게 중국하고 다를게 뭐냐... 와디즈...", "time": "11시간 전", "author": "양파"}',
#  '{"cid": "Ugz3Ysy3DS2adOt13UJ4AaABAg", "text": "저딴걸 왜함 한두번도 아니고 걍 안하면 되잖아", "time": "11시간 전", "author": "donguk Lee"}',
#  '{"cid": "UgzEOh5gvBqh1ZdJyvB4AaABAg", "text": "와디즈는 처음 취지가 무엇이였을까? 정말 투자가 필요한 좋은 제품의 기회를 없애 버리려고 작정한 것인가?", "time": "11시간 전", "author": "azi gagng"}',
#  '{"cid": "UgxlcMIZyPIN4ci-TM14AaABAg", "text": "와디즈 왜 사는거임~~~~진짜.......ㅠㅠ", "time": "11시간 전", "author": "곰곰이"}',
#  '{"cid": "UgxtDCkkAF0xIuT-Bht4AaABAg", "text": "진짜 그것이 알고싶다에 나와야겠네요ㅜㅜ", "time": "12시간 전", "author": "김현주"}',
#  '{"cid": "UgwtsEvdQnv617YrRyx4AaABAg", "text": "난 제일 궁금한게.\\n와디즈의 정해진 수수료 외에 와디즈 높은사람들 중에 누군가가 뒷돈을 받느냐 하는거임.\\n뒷돈을 받게되면 그게 족쇄가 되어서 잘못을 바로잡지 못하는 경우가 생기거든.", "time": "15시간 전", "author": "a"}',
#  '{"cid": "UgwDzUMs4miNQIvuDwd4AaABAg", "text": "유튜버 연결시켜서 펀딩 진행하는것도 보았는데 이 일을 모르고 했을까 그 유튜버", "time": "15시간 전", "author": "W tf"}',
#  '{"cid": "UgzTTe6QLH2wg6-Ssol4AaABAg", "text": "고소 당하실 것 같은데...\\n\\n\\n\\n\\n걱정돼서 하는 소리지 비꼰거나 그런 거 아니에요...", "time": "16시간 전", "author": "떼미"}',
#  '{"cid": "UgwDiP0fCLU5GDwn9NN4AaABAg", "text": "오.......................................................................", "time": "16시간 전", "author": "떼미"}',
#  '{"cid": "UgxwnYnOuyx6yvpWbbF4AaABAg", "text": "레알 그냥 와디바바(와디즈 + 알리바바) 실화냐? ㄷ", "time": "16시간 전(수정됨)", "author": "KaoKao"}',
#  '{"cid": "UgwtpX2CUv1hPv8eWFh4AaABAg", "text": "정말 위대합니다 선생!", "time": "16시간 전", "author": "노란딱지"}',
#  '{"cid": "UgzIIsr4nr4RjyFd5y54AaABAg", "text": "투자라면 개발품이라고 속이고 투자받은 기업은 사기죄에 해당하죠. 그렇다면 형사고발도 가능하지 않나요?", "time": "17시간 전", "author": "Appleseed"}',
#  '{"cid": "UgwJec2DPwfc0BlqvZh4AaABAg", "text": "아예 대놓고 앞에알바 두명 처풀어놨네ㅋㅋㅋㅋㅋㅋㄱ", "time": "17시간 전", "author": "밥김국"}',
#  '{"cid": "Ugw00t3HJhgRZEpanlh4AaABAg", "text": "바디보스는 가격폭리로 큰 이득을 취하고 있었는데 이것 또한 사기 아니냐? 싸게 만들어 파는것도 감사한줄 알어라 응근 마녀사냥이다. 이 히벌 호로놀루 색히야;. 가면쓰고 염병질한다,. 진짜. 너 헛점 한두가지가 아니야.", "time": "17시간 전(수정됨)", "author": "정태형"}',
#  '{"cid": "Ugw00t3HJhgRZEpanlh4AaABAg.99-1ZOeaVH499-69kZcqb2", "text": "야이 히벌~호로놀루 색희얏~응근 마뇨사냥이돳~", "time": "17시간 전", "author": "블베"}',
#  '{"cid": "Ugw3Ue4z9TX3nX3Rqpp4AaABAg", "text": "취지는 좋은데 이 히벌색히야. 사회 생활좀 하고 떠들어. 무순 영웅심리냐? 너도 엥간히 해라 진짜.", "time": "18시간 전", "author": "정태형"}',
#  '{"cid": "UgxKwku2kdTzmXxbuQ14AaABAg", "text": "대단행!", "time": "18시간 전", "author": "Yunho Lee"}',
#  '{"cid": "UgxPqEhn0B993EVyzKd4AaABAg", "text": "ㅋㅋㅋㅋㅋㅋ 머슬레인 링크 들어가자마자 첫 평가가 존나 웃기네 ㅋㅋㅋㅋ 아래는 그 평가임\\n\\n\'멍청이들아. 그럼 조명은 에디슨만 만들고, 자동차는 포드만 만드냐?\\r\\n쿠팡은 뭐냐? 현대도 카피켓이고 삼성도 카피켓이야.\\r\\n텐센트 마화텅 회장이 “우리가 외국 모델을 모방한 건 사실이다. 하지만 남들이 고양이를 보고 고양이를 그릴 때 우리는 고양이를 본 떠 사자를 그렸다”라고 했어.\\r\\n월마트 회장이 “내가 평생동안 한 일은 다른 창작자의 것을 모방 한 것이다”라고 했어.\\r\\nfast follower라고 경영학에도 있는 말이야.\\r\\n모르면 적당히 하자.\\r\\n이것도 마녀 사냥이야.\\r\\n더 좋은 가격에 더 경쟁력 있는 경쟁사가 나와서 시장 경쟁을 하는건 당연한거야.\\r\\n그게 소비자에게 이득을 주는 구조야.\\r\\n니네는 처음 만든 기업의 제품을 제품이 구리고 가격이 비싸도 도덕적이라고 하면서 사줄래?\\r\\n제발 멍청한 소리 그만하자.\'\\n\\n병신새끼", "time": "19시간 전", "author": "서현준"}',
#  '{"cid": "Ugwclf-WNC6VDZGONOd4AaABAg", "text": "이쯤되면 와디즈 펀딩하는사람이 문제인듯...", "time": "19시간 전", "author": "Alvin Jo"}',
#  '{"cid": "UgyWUBiDspPQTPnA83t4AaABAg", "text": "와디즈가 펀딩 성공시 가져가는 수익이 어느정도임??? 얼마나 비율이 크길래 취소를 안시키지?? 이야...", "time": "20시간 전", "author": "야미야미"}',
#  '{"cid": "UgxVNEtvtgUFiUhpCwZ4AaABAg", "text": "사기로 키운 1조", "time": "20시간 전", "author": "GD kim"}',
#  '{"cid": "UgxhqQ-KF7LwSoLWWg94AaABAg", "text": "[제보][e복지 피해 중소기업] 1,599만명의 중소기업인에게 꼭 알려주십시오 \\r\\n\\r\\n\\r\\n[e복지] 국민청원(기한: ~2020.05.29) 바로가기\\r\\nhttps://www1.president.go.kr/petitions/Temp/hfrfqA\\r\\n\\r\\n\\r\\n사망여우TV님, 안녕하세요\\r\\n늘 응원하고 있는 평범한 사람입니다. \\r\\n\\r\\n위의 국민청원과 아래 기사들의 250억원 피해사건 관련, 피해자이기도 합니다. \\r\\n\\r\\n* 이러한 상황에서 저는 어떻게 회사의 자금을 되돌려 받을 수 있을까요? 절박하고 간절한 마음에 여쭤봅니다. 자세한 내용이 필요하시면 언제든 연락을 부탁드립니다. \\r\\n\\r\\n\\n▣ 다음은 관련 기사들입니다. \\r\\n\\r\\n- [단독] 中企 복지서비스 대행 서비스 갑작스런 폐쇄에 경찰 수사\\r\\n2020.05.05, 매일경제\\r\\nhttps://www.mk.co.kr/news/society/view/2020/05/458251/\\r\\n\\r\\n\\r\\n- “공공기관인 줄 알았는데 다단계식 자격증 영업”…복지몰 먹튀에 피해액만 수십억대\\r\\n2020.05.06 10:10, 헤럴드경제  \\r\\nhttp://news.heraldcorp.com/view.php?ud=20200506000212\\r\\n\\r\\n\\r\\n▣ 다음은 활용하실 수 있는 영상자료입니다.\\r\\n\\r\\n- [SBS CNBC][이슈톡톡]가고 싶은 中企되려면…“토닥 e복지 활용하세요”\\r\\nhttps://tv.naver.com/v/9239846\\r\\n: 생생경제 정보톡톡 \'이슈 톡톡\' - 진행 : 김용필, 윤호연 \\r\\n\\r\\n- e복지_공식 유튜브 계정 ‘워라밸연구소’ \\r\\nhttps://youtu.be/9YMaHtmf_-g\\r\\n\\r\\n\\r\\n그리고 이와 관련하여 조회수 수십만, 수백만회를 넘는 사망여우TV님의 콘텐츠에서 다뤄주신다면, 이슈가 되고 수많은 피해기업들에게도 도움이 되고 힘이 되리라 기대됩니다. \\r\\n\\r\\n메일로도 더 상세한 제보를 전해드리겠습니다. 필요하신 부분 있을 시 언제든 연락을 부탁드립니다. \\n\\n\\n\\n감사합니다.", "time": "21시간 전", "author": "LINA LINA"}',
#  '{"cid": "UgxlbR11bdh70rldUd54AaABAg", "text": "이거 밴드에 \'와디즈\'를 쳐보니 와디즈 제품 관련 글에 사람들이 되게 많이 좋아요를 눌렀더군요...\\n이렇게 많이 속고계실줄은... 안타깝네요", "time": "21시간 전", "author": "한낱 전자"}',
#  '{"cid": "UgwT8Lc-qsQuWH-PsjZ4AaABAg", "text": "와디즈 진짜 개쓰레기 새끼들이네", "time": "22시간 전(수정됨)", "author": "yaho ho"}',
#  '{"cid": "Ugx94fP78XyK6i4Yq994AaABAg", "text": "와디즈 진짜 믿을게 못되요", "time": "22시간 전", "author": "근성있는테레비"}',
#  '{"cid": "UgzpK9UnGEmsHpI0UY54AaABAg", "text": "와디즈는 그냥 돈 찔러주면 짝퉁이든 사기제품이든 올려주는 병신사이트인듯", "time": "22시간 전", "author": "수붕이"}',
#  '{"cid": "UgxL4uU-pOsThHgGoJN4AaABAg", "text": "지금 환불 진행중입니다. 참고하세요\\nhttps://www.wadiz.kr/web/campaign/detailPost/58125", "time": "23시간 전", "author": "하연"}',
#  '{"cid": "UgxA_l9jyGWs8CKSC3t4AaABAg", "text": "사진 그대로 갖다쓴건 진짜 충격적이다..", "time": "23시간 전", "author": "a a"}',
#  '{"cid": "UgypR6CTGf5uJnprEGp4AaABAg", "text": "대한중화민국이네", "time": "23시간 전", "author": "전광석화"}',
#  '{"cid": "Ugw4F4SAQSgMZNQYewZ4AaABAg", "text": "와디즈 액션캠이후 넘실망커서 앞으로이용안할겁니다 사기들천지같아서요", "time": "23시간 전", "author": "씽달"}',
#  '{"cid": "UgzZZhOMTf1ZCUE3Bjt4AaABAg", "text": "왜 일반 유튜버가 하는걸 검찰은 못하는걸까 하는 생각을 해보면.. 한숨만 나오네요. 이정도면 범법인데...", "time": "23시간 전", "author": "z b"}',
#  '{"cid": "Ugxte_U3PBhBH5Q8t1h4AaABAg", "text": "진짜 열심히 만드는 기업들 다른 업체들은 불쌍하다...", "time": "1일 전", "author": "호호잇드림복서"}',
#  '{"cid": "UgynDRX0ThI-SADidpt4AaABAg", "text": "와디즈는  아이디어 훔쳐서 돈 벌어먹는 창구인가? (와디즈가 직접 했다는 얘기는 아닙니다... 아 돈 된다는 걸 보여줬으니 직접 한 건가)", "time": "1일 전", "author": "강아지"}',
#  '{"cid": "UgxdnkqHLBAOZ_7BrqN4AaABAg", "text": "와디즈 대체 뭐하는 기업이지? 중국에서 만든 기업인가 왤케 하는 짓이 쓰레기같아", "time": "1일 전", "author": "이공주"}',
#  '{"cid": "UgzvgKWWnEXKeNyOMid4AaABAg", "text": "쓰레기같은 놈들이 모여서 차린 쓰레기 회사에서 만든 쓰레기 복제품... 중국하고 뭐가 다르냐?", "time": "1일 전", "author": "Tony Seo"}',
#  '{"cid": "UgwQcQKbsNORlAKHb0d4AaABAg", "text": "와디즈 믿고 거른지 좀 되었다.. 덕분입니다", "time": "1일 전", "author": "썬칩"}',
#  '{"cid": "Ugy6ak2C69Yz_ygc6aN4AaABAg", "text": "와디즈가 개같은데 저렇게 놔두고 방관하면 개나소나 펀딩할꺼고 고객만 호구임", "time": "1일 전", "author": "azzera to"}',
#  '{"cid": "Ugzc5CRx5Y8kSReuF754AaABAg", "text": "앞으로 하실일은 펀팅을 법제도권에 들어오게 청원이라두 넣으셔야 펀딩으로 인한 피해자가 발생 안할듯 합니다.", "time": "1일 전", "author": "하얀"}',
#  '{"cid": "UgxFvPJbXiqBXwpZ7D14AaABAg", "text": "와디즈극혐이네 ㅋㅋㅋㅋㅋ 지들 받아쳐먹는금액 많으니깐ㅋㅋㅋㅋ", "time": "1일 전", "author": "thumbly_"}',
#  '{"cid": "Ugx9I7L5MkyyHgcq58h4AaABAg", "text": "힘내세요!!!!멋지십니다!!!", "time": "1일 전", "author": "콜라코카"}',
#  '{"cid": "UgxONcBJUt1J2sK4jbx4AaABAg", "text": "난 쫌 마음이 아파요 사망여우님 신박한 제품들 소개해주는게 좋아서 오래전에 구독했었는데 어쩌다가 이렇게까지 됐을까요... 사기치는것들 죄다 잡아다가 바다한가운데 떨궈놔야해요 사망여우님 항상 응원합니다. 혹시라도 법적인 소송들어온다면 꼭 유튜브에 남겨주세요. 작은 힘이나마 보태고 싶습니다", "time": "1일 전", "author": "EW H"}',
#  '{"cid": "UgzhOMoUJgZ9oe-ozFx4AaABAg", "text": "ㅋㅋㅋ 아나..검색해봤는데.. ㅋㅋㅋ 아 황당..스", "time": "1일 전", "author": "jy kim"}']

# %% [markdown]
# # 게시글

# %%
import requests
from bs4 import BeautifulSoup

keyword = '미르방'

req = requests.get('https://www.youtube.com/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&sp=CAISBAgEEAE%253D')
html = req.text
soup = BeautifulSoup(html, 'html.parser')
my_titles = soup.select(
    'h3 > a'
    )

title = []
url = []

for idx in my_titles:
    if idx.get('href')[:7] != '/watch?':
        pass
    else:
        title.append(idx.text)
        url.append(idx.get('href'))

# %%
import pandas as pd

# %%
title_list = pd.DataFrame(url, columns = ['url'])
title_list['title'] = title

# %%
title_list
# Out:
#                      url                                    title
# 0   /watch?v=sSCuDsrut0E                               와디즈 광고_죠죠편
# 1   /watch?v=F22cAbjUEeE         조금(많이)이상한 와디즈 광고 - 대복이가 bosin탕으로
# 2   /watch?v=6AwdXvIn9wg                           지극히 평범한 와디즈 광고
# 3   /watch?v=D_Z3MIp84DM                           5/23 공간 와디즈 👍🏻
# 4   /watch?v=Gk6_BFGrM8c                              와디즈도 뒤졌답니다!
# 5   /watch?v=f48ZYEE0wSg                        [와디즈 리워드 배송] 누기패드
# 6   /watch?v=h9MCq-vckro  와디즈, 디지털 마케팅,리워드,온라인 마케팅, 마소캠퍼스, 스터디파트너
# 7   /watch?v=OEAProYzxu8                            와디즈 마스크 대복이대왕
# 8   /watch?v=7CybGyhJxBI                공간 와디즈로 초대합니다!ㅣ플레이 공간 와디즈
# 9   /watch?v=JlgOg5f-Mzk            대복이가 출근하면서 와디즈에게 반겨줄 밈 (한글자막)
# 10  /watch?v=8Mh3G87fB8E                퀀트, 유튜브 채널 그리고 와디즈 2차 펀딩!
# 11  /watch?v=b8Cs9cAo7lE         와디즈펀딩 홍대 힐패치 발뒤꿈치 천연보습 각질제거 래핑시트
# 12  /watch?v=HQWGRiLPqcQ                        와디즈 광고 따라하기 메이킹필름
# 13  /watch?v=keBNqBC7JXs                          SMA SHOES | 와디즈
# 14  /watch?v=Pnq21vM4GDA                       NAPIER] 와디즈 감사영상 2
# 15  /watch?v=rbnwb0Z7Srg       최경훈 큐어라이프(쓰리잘비) MD가 와디즈에서 구매한 제품은?
# 16  /watch?v=xOHrzDykafQ                             사기 아니라면서요?..
# 17  /watch?v=YfnU1pYu5dM  [Sodamon 소다몬] 와디즈 어템핏 선글라스 알림 신청 이벤트 추첨
# 18  /watch?v=7Okf6q_DrRY   [Sodamon 소다몬] 와디즈 어템핏 선글라스오늘 펀딩 이벤트 추첨
# 19  /watch?v=zuJKg7v-2oE                       자연공유x와디즈, 매울 辛 쫀드기

# %%
title.get('href')[:7] == '/watch?'
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-571-49564fc87e73> in <module>
# ----> 1 title.get('href')[:7] == '/watch?'
#
# AttributeError: 'list' object has no attribute 'get'

# %%
my_titles = soup.select(
    'body'
    )

#video-title

# %%
my_titles
# Out:
# [<body class="visibility-logging-enabled ltr exp-invert-logo exp-kevlar-settings exp-mouseover-img exp-responsive exp-search-big-thumbs site-center-aligned site-as-giant-card guide-pinning-enabled appbar-hidden not-nirvana-dogfood delayed-frame-styles-not-in" data-spf-name="other" dir="ltr" id="body">
#  <div id="early-body"></div>
#  <div id="body-container"><div id="a11y-announcements-container" role="alert"><div id="a11y-announcements-message"></div></div><form action="/logout" method="POST" name="logoutForm"><input name="action_logout" type="hidden" value="1"/></form><div id="masthead-positioner"> <div id="ticker-content">
#  </div>
#  <div class="clearfix yt-base-gutter" id="yt-masthead-container"> <button class="skip-nav" data-target-id="main" id="a11y-skip-nav" tabindex="3">
#  탐색 건너뛰기
#    </button>
#  <div id="yt-masthead"><div class="yt-masthead-logo-container"> <button aria-controls="appbar-guide-menu" aria-label="가이드" class="yt-uix-button yt-uix-button-size-default yt-uix-button-text yt-uix-button-empty yt-uix-button-has-icon appbar-guide-toggle appbar-guide-clickable-ancestor" id="appbar-guide-button" onclick=";return false;" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-appbar-guide yt-sprite"></span></span></button>
#  <div id="appbar-main-guide-notification-container"></div>
#  <span id="yt-masthead-logo-fragment"><a class="masthead-logo-renderer yt-uix-sessionlink spf-link" data-sessionlink="itct=CAMQsV4iEwjhq4G6zcvpAhXBCFgKHUlsCbo" href="/" id="logo-container" title="YouTube 홈"> <span class="logo masthead-logo-renderer-logo yt-sprite" title="YouTube 홈"></span>
#  <span class="content-region">KR</span></a></span></div><div id="yt-masthead-signin"> <a class="yt-uix-button yt-uix-sessionlink yt-uix-button-opacity yt-uix-button-size-default yt-uix-button-has-icon yt-uix-tooltip yt-uix-button-empty" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=mhsb" href="//www.youtube.com/upload" id="upload-btn" title="업로드"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-material-upload yt-sprite"></span></span></a>
#  <div class="signin-container"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-primary" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;hl=ko&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26hl%3Dko%26next%3D%252Fresults%253Fsearch_query%253D%2525EC%252599%252580%2525EB%252594%252594%2525EC%2525A6%252588%26app%3Ddesktop%26feature%3Dsign_in_button" onclick=";window.location.href=this.getAttribute('href');return false;" role="link" type="button"><span class="yt-uix-button-content">로그인</span></button> <iframe id="signin-passive" src="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;hl=ko&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26hl%3Dko%26next%3D%252Fsignin_passive%26app%3Ddesktop%26feature%3Dpassive"></iframe>
#  </div></div><div id="yt-masthead-content"><form action="/results" class="search-form consolidated-form vve-check" data-clicktracking="CAEQ7VAiEwiXtf-5zcvpAhVrV4UKHZocC28o9CQ" data-visibility-tracking="CAEQ7VAiEwiXtf-5zcvpAhVrV4UKHZocC28o9CQ" id="masthead-search" onsubmit="if (document.getElementById('masthead-search-term').value == '') return false;"><button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default search-btn-component search-button" dir="ltr" id="search-btn" onclick="if (document.getElementById('masthead-search-term').value == '') return false; document.getElementById('masthead-search').submit(); return false;;return true;" tabindex="2" type="submit"><span class="yt-uix-button-content">검색</span></button><div class="masthead-search-terms-border" dir="ltr" id="masthead-search-terms"><input aria-label="검색" autocomplete="off" class="search-term masthead-search-renderer-input yt-uix-form-input-bidi" id="masthead-search-term" name="search_query" onkeydown="if (!this.value &amp;&amp; (event.keyCode == 40 || event.keyCode == 32 || event.keyCode == 34)) {this.onkeydown = null; this.blur();}" placeholder="검색" tabindex="1" title="검색" type="text" value="와디즈"/></div></form></div></div></div>
#  <div class="clearfix" id="masthead-appbar-container"><div id="masthead-appbar"><div class="" id="appbar-content"></div></div></div>
#  </div><div id="masthead-positioner-height-offset"></div><div id="page-container"><div class="search branded-page-v2-secondary-column-wide no-flex clearfix" id="page"><div class="yt-scrollbar" id="guide"> <div class="appbar-menu appbar-guide-menu-layout appbar-guide-clickable-ancestor yt-uix-scroller yt-uix-tdl" id="appbar-guide-menu" role="navigation">
#  <div id="guide-container">
#  <div class="guide-module-content yt-scrollbar">
#  <ul class="guide-toplevel">
#  <li class="guide-section vve-check" data-visibility-tracking="CAwQ5isYACITCN_AgbrNy-kCFW9A9QUdDj4LSg==">
#  <div class="guide-item-container personal-item">
#  <ul class="guide-user-links yt-uix-tdl yt-box" role="menu">
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CBAQtSwYACITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="what_to_watch-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="what_to_watch" data-serialized-endpoint="0qDduQEREg9GRXdoYXRfdG9fd2F0Y2g%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-system&amp;ved=CAUQtSwYACITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CBAQtSwYACITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/" title="홈">
#  <span class="yt-valign-container">
#  <span class="thumb guide-what-to-watch-icon yt-sprite"></span>
#  <span class="display-name no-count">
#  <span>
#              홈
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CA8QtSwYASITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="trending-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="trending" data-serialized-endpoint="0qDduQEMEgpGRXRyZW5kaW5n" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-trending&amp;ved=CAYQtSwYASITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CA8QtSwYASITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/feed/trending" title="인기">
#  <span class="yt-valign-container">
#  <span class="thumb guide-trending-icon yt-sprite"></span>
#  <span class="display-name no-count">
#  <span>
#              인기
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CA4QtSwYAiITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="history-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="history" data-serialized-endpoint="0qDduQELEglGRWhpc3Rvcnk%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-personal&amp;ved=CAcQtSwYAiITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CA4QtSwYAiITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/feed/history" title="시청 기록">
#  <span class="yt-valign-container">
#  <span class="thumb guide-history-icon yt-sprite"></span>
#  <span class="display-name no-count">
#  <span>
#              시청 기록
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CA0QmbcBGAMiEwjfwIG6zcvpAhVvQPUFHQ4-C0o=" id="unlimited-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="unlimited" data-serialized-endpoint="0qDduQENEgtTUHVubGltaXRlZA%3D%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;ved=CAgQtSwYAyITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CA0QmbcBGAMiEwjfwIG6zcvpAhVvQPUFHQ4-C0o=" href="/premium" title="YouTube Premium 가입">
#  <span class="yt-valign-container">
#  <span class="thumb guide-video-youtube-red-icon yt-sprite"></span>
#  <span class="display-name no-count">
#  <span>
#              YouTube Premium 가입
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <hr class="guide-section-separator"/>
#  </li>
#  <li class="guide-section vve-check" data-visibility-tracking="CAMQ5isYASITCN_AgbrNy-kCFW9A9QUdDj4LSg==">
#  <div class="guide-item-container personal-item">
#  <h3>
#        인기 YouTube
#      </h3>
#  <ul class="guide-user-links yt-uix-tdl yt-box" role="menu">
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAsQtSwYACITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="UC-9-kyTW8ZkZNDHQJ6FgpwQ-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UC-9-kyTW8ZkZNDHQJ6FgpwQ" data-serialized-endpoint="0qDduQEaEhhVQy05LWt5VFc4WmtaTkRIUUo2Rmdwd1E%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel&amp;ved=CAoQtSwYACITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAsQtSwYACITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/channel/UC-9-kyTW8ZkZNDHQJ6FgpwQ" title="음악">
#  <span class="yt-valign-container">
#  <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
#  <span class="yt-thumb-square">
#  <span class="yt-thumb-clip">
#  <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/-rk1ZK5MQ0Egwvt2d2oH_oxuDnk8gUcd08pSNsZCIhuFGV21dzkm4q_BciHSsrkohKYMVI5Zyg=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
#  <span class="vertical-align"></span>
#  </span>
#  </span>
#  </span>
#  </span>
#  <span class="display-name no-count">
#  <span>
#              음악
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAoQtSwYASITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="UCEgdi0XIXXZ-qJOFPf4JSKw-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCEgdi0XIXXZ-qJOFPf4JSKw" data-serialized-endpoint="0qDduQEaEhhVQ0VnZGkwWElYWFotcUpPRlBmNEpTS3c%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel&amp;ved=CAsQtSwYASITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAoQtSwYASITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/channel/UCEgdi0XIXXZ-qJOFPf4JSKw" title="스포츠">
#  <span class="yt-valign-container">
#  <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
#  <span class="yt-thumb-square">
#  <span class="yt-thumb-clip">
#  <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/FUQCs4oBWPC01zad2qEJMQl5_2pXPe0Y9j-pQ9XlHHJxwlA8b-dOe3OsjCin5b-95JOdJ756Jw=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
#  <span class="vertical-align"></span>
#  </span>
#  </span>
#  </span>
#  </span>
#  <span class="display-name no-count">
#  <span>
#              스포츠
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAkQtSwYAiITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="UCOpNcN46UbXVtpKMrmU4Abg-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCOpNcN46UbXVtpKMrmU4Abg" data-serialized-endpoint="0qDduQEaEhhVQ09wTmNONDZVYlhWdHBLTXJtVTRBYmc%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel&amp;ved=CAwQtSwYAiITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAkQtSwYAiITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/gaming" title="게임">
#  <span class="yt-valign-container">
#  <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
#  <span class="yt-thumb-square">
#  <span class="yt-thumb-clip">
#  <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/t0ca5_yRYy2slE9sdYJg_vTyBGGbHk9eTAq-kU1xXrC2o9phCcg8riiDU1nJOIiBNiXa0mu6aw=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
#  <span class="vertical-align"></span>
#  </span>
#  </span>
#  </span>
#  </span>
#  <span class="display-name no-count">
#  <span>
#              게임
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAgQtSwYAyITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="UClgRkhTL3_hImCAmdLfDE4g-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UClgRkhTL3_hImCAmdLfDE4g" data-serialized-endpoint="0qDduQEaEhhVQ2xnUmtoVEwzX2hJbUNBbWRMZkRFNGc%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel&amp;ved=CA0QtSwYAyITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAgQtSwYAyITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/channel/UClgRkhTL3_hImCAmdLfDE4g" title="영화">
#  <span class="yt-valign-container">
#  <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
#  <span class="yt-thumb-square">
#  <span class="yt-thumb-clip">
#  <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/ZEAue1qwTmAspl5Xhn8rC_AXpCi-77WPoA9xRRerMehlpxdYrp8b6tO3cWL33p8806l4kYjhAg=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
#  <span class="vertical-align"></span>
#  </span>
#  </span>
#  </span>
#  </span>
#  <span class="display-name no-count">
#  <span>
#              영화
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAcQtSwYBCITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="UCYfdidRxbB8Qhf0Nx7ioOYw-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCYfdidRxbB8Qhf0Nx7ioOYw" data-serialized-endpoint="0qDduQEaEhhVQ1lmZGlkUnhiQjhRaGYwTng3aW9PWXc%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel&amp;ved=CA4QtSwYBCITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAcQtSwYBCITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/channel/UCYfdidRxbB8Qhf0Nx7ioOYw" title="뉴스">
#  <span class="yt-valign-container">
#  <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
#  <span class="yt-thumb-square">
#  <span class="yt-thumb-clip">
#  <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/J3RmNCh8bo-uzAqoPyL9WzRifYBxoL29-sNTpKkoEIZpesiDQN0Jf4V7lOssR7Rma0piui4k8w=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
#  <span class="vertical-align"></span>
#  </span>
#  </span>
#  </span>
#  </span>
#  <span class="display-name no-count">
#  <span>
#              뉴스
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAYQtSwYBSITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="UC4R8DWoMoI7CAwX8_LjQHig-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UC4R8DWoMoI7CAwX8_LjQHig" data-serialized-endpoint="0qDduQEaEhhVQzRSOERXb01vSTdDQXdYOF9MalFIaWc%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel&amp;ved=CA8QtSwYBSITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAYQtSwYBSITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/channel/UC4R8DWoMoI7CAwX8_LjQHig" title="실시간">
#  <span class="yt-valign-container">
#  <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
#  <span class="yt-thumb-square">
#  <span class="yt-thumb-clip">
#  <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/5HkUAx2SOolanKFGX7Au5O84m4XbzvjpxXowcw2EYjbZmUObb_MzjZiiSDfy3z9ImpC0PCuZIB_dlPnEqQ=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
#  <span class="vertical-align"></span>
#  </span>
#  </span>
#  </span>
#  </span>
#  <span class="display-name no-count">
#  <span>
#              실시간
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAUQtSwYBiITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="UCtFRv9O2AHqOZjjynzrv-xg-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCtFRv9O2AHqOZjjynzrv-xg" data-serialized-endpoint="0qDduQEaEhhVQ3RGUnY5TzJBSHFPWmpqeW56cnYteGc%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel&amp;ved=CBAQtSwYBiITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAUQtSwYBiITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/learning" title="학습">
#  <span class="yt-valign-container">
#  <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
#  <span class="yt-thumb-square">
#  <span class="yt-thumb-clip">
#  <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/fzFgHfr1eC1dbj27ptbM_rSwKdn6OcdhUqiZR-Hfoc5yT5VxMz4oeZn19zrI9yzaSkxmB31J=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
#  <span class="vertical-align"></span>
#  </span>
#  </span>
#  </span>
#  </span>
#  <span class="display-name no-count">
#  <span>
#              학습
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAQQtSwYByITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="UCzuqhhs6NWbgTzMuM09WKDQ-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="UCzuqhhs6NWbgTzMuM09WKDQ" data-serialized-endpoint="0qDduQEaEhhVQ3p1cWhoczZOV2JnVHpNdU0wOVdLRFE%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel&amp;ved=CBEQtSwYByITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAQQtSwYByITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/channel/UCzuqhhs6NWbgTzMuM09WKDQ" title="360° 동영상">
#  <span class="yt-valign-container">
#  <span class="thumb"> <span class="video-thumb yt-thumb yt-thumb-20">
#  <span class="yt-thumb-square">
#  <span class="yt-thumb-clip">
#  <img alt="" aria-hidden="true" data-thumb="//yt3.ggpht.com/OjYeEh2K5C8lNeepBqDD24olrapB922Ciw1EM-P5s0sLpzGjh1ECycXmn0c9eDuToTM_J3iPfA=s20-c-k-c0xffffffff-no-nd-rj" data-ytimg="1" height="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="/yts/img/pixel-vfl3z5WfW.gif" width="20"/>
#  <span class="vertical-align"></span>
#  </span>
#  </span>
#  </span>
#  </span>
#  <span class="display-name no-count">
#  <span>
#              360° 동영상
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <hr class="guide-section-separator"/>
#  </li>
#  <li class="guide-section vve-check" data-visibility-tracking="CAEQ5isYAiITCN_AgbrNy-kCFW9A9QUdDj4LSg==">
#  <div class="guide-item-container personal-item">
#  <ul class="guide-user-links yt-uix-tdl yt-box" role="menu">
#  <li class="vve-check guide-channel guide-notification-item overflowable-list-item" data-visibility-tracking="CAIQtSwYACITCN_AgbrNy-kCFW9A9QUdDj4LSg==" id="guide_builder-guide-item" role="menuitem">
#  <a class="guide-item yt-uix-sessionlink yt-valign spf-link" data-external-id="guide_builder" data-serialized-endpoint="0qDduQEREg9GRWd1aWRlX2J1aWxkZXI%3D" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-manage&amp;ved=CBMQtSwYACITCJe1_7nNy-kCFWtXhQodmhwLbyj0JA" data-visibility-tracking="CAIQtSwYACITCN_AgbrNy-kCFW9A9QUdDj4LSg==" href="/feed/guide_builder" title="채널 탐색">
#  <span class="yt-valign-container">
#  <span class="thumb guide-builder-icon yt-sprite"></span>
#  <span class="display-name no-count">
#  <span>
#              채널 탐색
#            </span>
#  </span>
#  </span>
#  </a>
#  </li>
#  </ul>
#  </div>
#  <hr class="guide-section-separator"/>
#  </li>
#  <li class="guide-section guide-header signup-promo">
#  <p>
#        로그인하면 동영상에 좋아요를 표시하고 댓글을 달거나 구독할 수 있습니다.
#      </p>
#  <div class="signed-out clearfix" id="guide-builder-promo-buttons">
#  <a class="yt-uix-button yt-uix-sessionlink yt-uix-button-primary yt-uix-button-size-default" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;hl=ko&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26hl%3Dko%26next%3D%252Fresults%253Fsearch_query%253D%2525EC%252599%252580%2525EB%252594%252594%2525EC%2525A6%252588%26app%3Ddesktop%26feature%3Dsign_in_promo"><span class="yt-uix-button-content">로그인</span></a>
#  </div>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>
#  <div class="hid" id="appbar-guide-notifications">
#  <div id="appbar-guide-notification-watch-later-video-added">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >나중에 볼 동영상에 추가됨</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-watch-later-video-removed">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >나중에 볼 동영상에서 삭제되었습니다.</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-subscription">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >구독이 추가되었습니다.</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-unsubscription">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >구독정보가 삭제되었습니다.</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-playlist-like">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >재생목록에 저장되었습니다.</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-playlist-unlike">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >재생목록에서 삭제되었습니다.</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-playlist-video-added">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >재생목록에 추가됨</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-playlist-video-removed">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >재생목록에서 삭제됨</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-video-like">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >좋아요 표시한 동영상에 추가됨</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-video-unlike">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >좋아요 표시한 동영상에서 삭제됨</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-event-reminder-set">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >이 이벤트에 대한 알림이 설정되었습니다.</span></span></div>
#      -->
#  </div>
#  <div id="appbar-guide-notification-event-reminder-removed">
#  <!--
#      <div class="appbar-guide-notification " role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" >이벤트 알림이 삭제되었습니다.</span></span></div>
#      -->
#  </div>
#  </div>
#  <div class="hid" id="appbar-guide-item-templates">
#  <div id="appbar-guide-item-template-playlist">
#  <!--
#
#    <li class="vve-check guide-channel guide-notification-item overflowable-list-item show-insertion-notification " id="__ID__-guide-item"
#   data-visibility-tracking="" role="menuitem">
#
#    <a class="guide-item yt-uix-sessionlink yt-valign spf-nolink    "
#      href="__URL__"
#      title="__TITLE__"
#      data-serialized-endpoint="" data-external-id="__ID__" data-visibility-tracking="" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-playlists"
#    >
#      <span class="yt-valign-container">
#          <span class="thumb guide-playlists-icon yt-sprite"></span>
#          <span class="display-name  no-count">
#            <span>
#              __TITLE__
#            </span>
#          </span>
#      </span>
#    </a>
#
#        <div class="appbar-guide-notification guide-item-insertion-notification" role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" aria-label="재생목록에 저장되었습니다.">__NOTIFICATION_OVERLAY_MESSAGE__</span></span></div>
#    </li>
#
#        -->
#  </div>
#  <div id="appbar-guide-item-template-mix">
#  <!--
#
#    <li class="vve-check guide-channel guide-notification-item overflowable-list-item show-insertion-notification " id="__ID__-guide-item"
#   data-visibility-tracking="" role="menuitem">
#
#    <a class="guide-item yt-uix-sessionlink yt-valign spf-nolink    "
#      href="__URL__"
#      title="__TITLE__"
#      data-serialized-endpoint="" data-external-id="__ID__" data-visibility-tracking="" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-playlists"
#    >
#      <span class="yt-valign-container">
#          <span class="thumb guide-mix-icon yt-sprite"></span>
#          <span class="display-name  no-count">
#            <span>
#              __TITLE__
#            </span>
#          </span>
#      </span>
#    </a>
#
#        <div class="appbar-guide-notification guide-item-insertion-notification" role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" aria-label="재생목록에 저장되었습니다.">__NOTIFICATION_OVERLAY_MESSAGE__</span></span></div>
#    </li>
#
#        -->
#  </div>
#  <div id="appbar-guide-item-template-channel">
#  <!--
#
#    <li class="vve-check guide-channel guide-notification-item overflowable-list-item show-insertion-notification " id="__ID__-guide-item"
#   data-visibility-tracking="" role="menuitem">
#
#    <a class="guide-item yt-uix-sessionlink yt-valign spf-nolink    "
#      href="__URL__"
#      title="__TITLE__"
#      data-serialized-endpoint="" data-external-id="__ID__" data-visibility-tracking="" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg&amp;feature=g-channel"
#    >
#      <span class="yt-valign-container">
#          <span class="thumb">  <span class="video-thumb  yt-thumb yt-thumb-20"
#      >
#      <span class="yt-thumb-square">
#        <span class="yt-thumb-clip">
#
#    <img alt="" aria-hidden="true" src="__THUMBNAIL_URL__" height="20" width="20" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" data-ytimg="1" >
#
#          <span class="vertical-align"></span>
#        </span>
#      </span>
#    </span>
#  </span>
#          <span class="display-name  no-count">
#            <span>
#              __TITLE__
#            </span>
#          </span>
#      </span>
#    </a>
#
#        <div class="appbar-guide-notification guide-item-insertion-notification" role="alert"><span class="appbar-guide-notification-content-wrapper yt-valign"><span class="appbar-guide-notification-icon yt-sprite"></span><span class="appbar-guide-notification-text-content" aria-label="구독이 추가되었습니다.">__NOTIFICATION_OVERLAY_MESSAGE__</span></span></div>
#    </li>
#
#        -->
#  </div>
#  </div>
#  </div><div class="alerts-wrapper"><div class="content-alignment" id="alerts"> <div class="yt-alert yt-alert-default yt-alert-warn" id="old-browser-alert"> <div class="yt-alert-icon">
#  <span class="icon master-sprite yt-sprite"></span>
#  </div>
#  <div class="yt-alert-content" role="alert"> <div class="yt-alert-message" tabindex="0">
#              이 브라우저는 곧 지원 중단됩니다. 최적의 환경을 위해 <a href="/supported_browsers">브라우저를 업데이트</a>하세요.
#
#      </div>
#  </div><div class="yt-alert-buttons"></div></div>
#  </div></div><div id="header">
#  </div><div class="off-screen" id="player" role="complementary"><div class="player-height" id="theater-background"></div> <div id="player-mole-container">
#  <div class="hid" id="player-unavailable">
#  </div>
#  <div class="player-width player-height off-screen-target player-api" id="player-api" tabindex="-1"></div>
#  <script>if (window.ytcsi) {window.ytcsi.tick("cfg", null, '');}</script>
#  <script>var ytplayer = ytplayer || {};ytplayer.config = {"args":{"enablejsapi":"1","cr":"KR","host_language":"ko","hl":"ko_KR","fexp":"23744176,23804281,23836023,23837040,23837993,23839597,23856950,23859802,23860859,23865856,23868321,23876129,23876171,23876458,23880389,23880718,23882502,23882514,23884386,23886825,23891857,23892587,23898053,23900839,23901950,23902104,23904809,23906756,24630994,9449243","fflags":"html5_jumbo_mobile_subsegment_readahead_target=3.0\u0026use_new_skip_icon=true\u0026fixed_padding_skip_button=true\u0026max_resolution_for_white_noise=360\u0026html5_live_abr_head_miss_fraction=0.0\u0026html5_sticky_duration_cap_secs=0\u0026pass_biscotti_id_in_header_ajax=true\u0026fast_autonav_in_background=true\u0026enable_client_deferred_full_screen_filtering_for_mweb_phones=true\u0026html5_deadzone_multiplier=1.0\u0026html5_jumbo_ull_nonstreaming_mffa_ms=4000\u0026web_player_inline_botguard=true\u0026ensure_vis_persists_in_full_screen_for_mweb=true\u0026forced_brand_precap_duration_ms=2000\u0026web_player_ios_mweb_resizing=true\u0026web_op_signal_type_blacklist=()\u0026survey_bypass_if_whitelisted=true\u0026use_sonic_js_library_for_v4_support=true\u0026html5_minimum_readahead_seconds=0.0\u0026set_interstitial_advertisers_question_text=true\u0026html5_time_based_consolidation_ms=10\u0026desktop_action_companion_wta_support=true\u0026html5_min_upgrade_health=0\u0026html5_live_low_latency_bandwidth_window=0.0\u0026external_fullscreen_with_edu=true\u0026info_cards_renderer_on_desktop=true\u0026player_doubletap_to_seek=true\u0026html5_disable_manifestless_sqless_sync=true\u0026enable_live_premiere_web_player_indicator=true\u0026html5_seek_jiggle_cmt_disable_gapless=true\u0026dash_manifest_version=5\u0026enable_device_forwarding_from_polymer_network_manager=true\u0026html5_background_quality_cap=360\u0026allow_live_autoplay=true\u0026variable_load_timeout_ms=0\u0026html5_request_size_padding_secs=3.0\u0026mdx_enable_privacy_disclosure_ui=true\u0026html5_prefer_server_bwe3=true\u0026html5_av1_thresh=1080\u0026html5_max_readahead_bandwidth_cap=0\u0026web_player_sentinel_is_uniplayer=true\u0026html5_hls_min_video_height=0\u0026player_bootstrap_method=true\u0026should_clear_video_data_on_player_cued_unstarted=true\u0026html5_ios7_force_play_on_stall=true\u0026html5_vp9_mime_full_range_flag=true\u0026web_player_watch_next_response_parsing=true\u0026html5_gllat=true\u0026html5_crypto_period_secs_from_emsg=true\u0026show_interstitial_white=true\u0026html5_no_placeholder_rollbacks=true\u0026network_polling_interval=30000\u0026disable_ad_info_event_for_music_web=true\u0026html5_manifestless_vp9=true\u0026info_cards_renderer_on_desktop_ads=true\u0026html5_streaming_xhr_try_webm=true\u0026web_yt_config_context=true\u0026html5_max_headm_for_streaming_xhr=0\u0026debug_sherlog_username=\u0026html5_seek_set_cmt_delay_ms=2000\u0026html5_fludd_suspend=true\u0026html5_subsegment_readahead_timeout_secs=2.0\u0026html5_ignore_bad_bitrates=true\u0026endscreen_renderer_on_desktop=true\u0026html5_suspend_loader=true\u0026html5_hfr_quality_cap=0\u0026use_button_command_field_for_web_survey_interstitial=true\u0026html5_autoplay_default_quality_cap=0\u0026html5_hdr_separate_keys_support=true\u0026html5_set_exception_to_nonfatal=true\u0026html5_seek_timeout_delay_ms=20000\u0026web_gel_timeout_cap=true\u0026disable_legacy_desktop_remote_queue=true\u0026web_player_api_logging_fraction=0.01\u0026html5_restrict_streaming_xhr_on_sqless_requests=true\u0026html5_live_ultra_low_latency_bandwidth_window=0.0\u0026html5_subsegment_readahead_load_speed_check_interval=0.5\u0026html5_unrewrite_timestamps=true\u0026html5_gapless_ad_byterate_multiplier=1.6\u0026html5_subsegment_readahead_min_buffer_health_secs=0.25\u0026web_player_disable_ima_uvr=true\u0026player_allow_autonav_after_playlist=true\u0026live_fresca_scheduled_persistent=true\u0026html5_gapless_max_played_ranges=12\u0026mweb_enable_custom_control_shared=true\u0026ad_pod_disable_companion_persist_ads_q ...
#  <div class="video-mole mole-collapsed hid" id="watch-queue-mole"><div class="watch-playlist player-height" id="watch-queue"><div class="main-content"><div class="watch-queue-header"><div class="watch-queue-info"><div class="watch-queue-info-icon"><span class="tv-queue-list-icon yt-sprite"></span></div><h3 class="watch-queue-title">동영상 대기열</h3><h3 class="tv-queue-title">목록</h3><span class="tv-queue-details"></span></div><div class="watch-queue-control-bar control-bar-button"><div class="watch-queue-mole-info"><div class="watch-queue-control-bar-icon"><span class="watch-queue-icon yt-sprite"></span></div><div class="watch-queue-title-container"><span class="watch-queue-count"></span><span class="watch-queue-title">동영상 대기열</span><span class="tv-queue-title">목록</span></div></div> <span class="dark-overflow-action-menu">
#  <button aria-expanded="false" aria-haspopup="true" aria-label="대기열에 해당하는 작업" class="flip control-bar-button yt-uix-button yt-uix-button-dark-overflow-action-menu yt-uix-button-size-default yt-uix-button-has-icon no-icon-markup yt-uix-button-empty" onclick=";return false;" type="button"><span class="yt-uix-button-arrow yt-sprite"></span><ul aria-haspopup="true" class="watch-queue-menu yt-uix-button-menu yt-uix-button-menu-dark-overflow-action-menu hid" role="menu"><li role="menuitem"><span class="watch-queue-menu-choice overflow-menu-choice yt-uix-button-menu-item" data-action="remove-all" onclick=";return false;">전체 삭제</span></li><li role="menuitem"><span class="watch-queue-menu-choice overflow-menu-choice yt-uix-button-menu-item" data-action="disconnect" onclick=";return false;">연결 해제</span></li></ul></button>
#  </span>
#  <div class="watch-queue-controls">
#  <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button prev-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" onclick=";return false;" title="이전 동영상" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-prev yt-sprite"></span></span></button>
#  <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button play-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" onclick=";return false;" title="재생" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-play yt-sprite"></span></span></button>
#  <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button pause-watch-queue-button yt-uix-button-opacity yt-uix-tooltip hid yt-uix-tooltip" onclick=";return false;" title="일시중지" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-pause yt-sprite"></span></span></button>
#  <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-empty yt-uix-button-has-icon control-bar-button next-watch-queue-button yt-uix-button-opacity yt-uix-tooltip yt-uix-tooltip" onclick=";return false;" title="다음 동영상" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-watch-queue-next yt-sprite"></span></span></button>
#  </div>
#  </div><div class="autoplay-dismiss-bar fade-out"><span class="autoplay-dismiss-title-label">다음 동영상 시작하는 중</span><span><button class="yt-uix-button yt-uix-button-size-default autoplay-dismiss-button yt-uix-tooltip" onclick=";return false;" title="중지" type="button"><span class="yt-uix-button-content">중지</span></button></span></div></div><div class="watch-queue-items-container yt-scrollbar-dark yt-scrollbar"><div class="yt-uix-scroller playlist-videos-list"><ol class="watch-queue-items-list" data-scroll-action="yt.www.watchqueue.loadThumbnails"> <p class="yt-spinner">
#  <span class="yt-spinner-img yt-sprite" title="로드 중 아이콘"></span>
#  <span class="yt-spinner-message">
#  로드 중...
#      </span>
#  </p>
#  </ol><div class="autoplay-control-container yt-uix-scroller-scroll-unit hid"> <div class="autoplay-control-bar">
#  <label class="autoplay-label" for="autoplay-toggle-id"></label>
#  <label class="yt-uix-form-input-checkbox-container yt-uix-form-input-container yt-uix-form-input-paper-toggle-container"><input class="yt-uix-form-input-checkbox" id="autoplay-toggle-id" type="checkbox"><div class="yt-uix-form-input-paper-toggle-bg yt-uix-form-input-paper-toggle-bar"></div><div class="yt-uix-form-input-paper-toggle-bg yt-uix-form-input-paper-toggle-button"></div></input></label>
#  </div>
#  </div><div class="up-next-item-container hid"></div></div></div></div> <div class="hid">
#  <div id="watch-queue-title-msg">
#  동영상 대기열
#      </div>
#  <div id="tv-queue-title-msg">목록</div>
#  <div id="watch-queue-count-msg">
#  전체 __total__개 중 __count__개
#      </div>
#  <div id="watch-queue-loading-template">
#  <!--
#            <p class="yt-spinner ">
#          <span title="로드 중 아이콘" class="yt-spinner-img  yt-sprite"></span>
#
#      <span class="yt-spinner-message">
#  로드 중...
#      </span>
#    </p>
#
#        -->
#  </div>
#  </div>
#  </div></div>
#  <div class="hid" id="player-playlist">
#  </div>
#  </div>
#  <div class="clear"></div>
#  </div><div class="content-alignment" id="content" role="main">
#  <div class="branded-page-v2-container branded-page-base-bold-titles branded-page-v2-container-flex-width">
#  <div class="branded-page-v2-col-container">
#  <div class="branded-page-v2-col-container-inner">
#  <div class="branded-page-v2-primary-col">
#  <div class="yt-card clearfix">
#  <div class="branded-page-v2-primary-col-header-container branded-page-v2-primary-column-content">
#  </div>
#  <div class="branded-page-v2-body branded-page-v2-primary-column-content" id="">
#  <noscript>
#  <div class="yt-alert yt-alert-default yt-alert-error"> <div class="yt-alert-icon">
#  <span class="icon master-sprite yt-sprite"></span>
#  </div>
#  <div class="yt-alert-content" role="alert"> <div class="yt-alert-message" tabindex="0">
#              자바스크립트가 사용 중지된 것 같습니다. 검색결과를 제대로 보려면 자바스크립트를 사용하도록 설정하세요.
#      </div>
#  </div><div class="yt-alert-buttons"><button aria-label="닫기" class="yt-uix-button yt-uix-button-size-default yt-uix-button-close close yt-uix-close" data-close-parent-class="yt-alert" onclick=";return false;" type="button"><span class="yt-uix-button-content">닫기</span></button></div></div>
#  </noscript>
#  <div id="results">
#  <ol class="section-list" id="section-list-032296">
#  <li class="branded-page-v2-subnav-container branded-page-gutter-padding"><div class="search-header yt-uix-expander yt-uix-expander-collapsed"><div class="filter-top"><div class="filter-bar-container"><div class="filter-button-container"><button aria-label="검색 필터" class="yt-uix-button yt-uix-button-size-small yt-uix-button-default filter-button yt-uix-expander-head" data-button-action="" data-button-menu-id="some-nonexistent-menu" data-button-toggle="true" onclick=";return false;" type="button"><span class="yt-uix-button-content">필터</span><span class="yt-uix-button-arrow yt-sprite"></span></button></div><div class="filter-crumb-spacer"></div></div></div><div class="yt-uix-expander-body" id="filter-dropdown"><div class="filter-col"><h4 class="filter-col-title">업로드 날짜</h4><ul><li><a aria-label="지난 1시간 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CCUQk3UYACITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIIAQ%253D%253D" title="지난 1시간 검색"><span class="filter-text filter-ghost">지난 1시간</span></a></li><li><a aria-label="오늘 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CCQQk3UYASITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIIAg%253D%253D" title="오늘 검색"><span class="filter-text filter-ghost">오늘</span></a></li><li><a aria-label="이번 주 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CCMQk3UYAiITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIIAw%253D%253D" title="이번 주 검색"><span class="filter-text filter-ghost">이번 주</span></a></li><li><a aria-label="이번 달 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CCIQk3UYAyITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIIBA%253D%253D" title="이번 달 검색"><span class="filter-text filter-ghost">이번 달</span></a></li><li><a aria-label="올해 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CCEQk3UYBCITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIIBQ%253D%253D" title="올해 검색"><span class="filter-text filter-ghost">올해</span></a></li></ul></div><div class="filter-col"><h4 class="filter-col-title">구분</h4><ul><li><a aria-label="동영상 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CB8Qk3UYACITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIQAQ%253D%253D" title="동영상 검색"><span class="filter-text filter-ghost">동영상</span></a></li><li><a aria-label="채널 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CB4Qk3UYASITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIQAg%253D%253D" title="채널 검색"><span class="filter-text filter-ghost">채널</span></a></li><li><a aria-label="재생목록 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CB0Qk3UYAiITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIQAw%253D%253D" title="재생목록 검색"><span class="filter-text filter-ghost">재생목록</span></a></li><li><a aria-label="영화 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CBwQk3UYAyITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIQBA%253D%253D" title="영화 검색"><span class="filter-text filter-ghost">영화</span></a></li><li><a aria-label="프로그램 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CBsQk3UYBCITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94%EC%A6%88&amp;sp=EgIQBQ%253D%253D" title="프로그램 검색"><span class="filter-text filter-ghost">프로그램</span></a></li></ul></div><div class="filter-col"><h4 class="filter-col-title">길이</h4><ul><li><a aria-label="단편(4분 이하) 검색" class="filter yt-uix-sessionlink spf-link" data-sessionlink="itct=CBkQk3UYACITCOGrgbrNy-kCFcEIWAodSWwJug" href="/results?search_query=%EC%99%80%EB%94%94% ...
#  <li>
#  <ol class="item-section" id="item-section-021652">
#  <li><div class="yt-lockup yt-lockup-tile yt-lockup-channel vve-check clearfix yt-uix-tile" data-visibility-tracking="CFAQ2jAYACITCOGrgbrNy-kCFcEIWAodSWwJug=="><div class="yt-lockup-thumbnail"><a aria-hidden="true" class="yt-uix-sessionlink spf-link" data-sessionlink="itct=CFAQ2jAYACITCOGrgbrNy-kCFcEIWAodSWwJug" href="/channel/UCuyN3WjEZW41qVji8TWUPeQ"><div class="yt-thumb video-thumb"><span class="yt-thumb-simple">
#  <img alt="" data-ytimg="1" height="138" onload=";window.__ytRIL &amp;&amp; __ytRIL(this)" src="//yt3.ggpht.com/a/AATXAJzoe0kVvs1LO76pMjMG4XrmuSVp4jq6UQuoqQ=s176-c-k-c0x00ffffff-no-rj-mo" width="138"/>
#  </span></div></a></div><div class="yt-lockup-content"><h3 class="yt-lockup-title"><a aria-describedby="description-id-610521" class="yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink spf-link" data-sessionlink="itct=CFAQ2jAYACITCOGrgbrNy-kCFcEIWAodSWwJug" dir="ltr" href="/channel/UCuyN3WjEZW41qVji8TWUPeQ" title="사망여우TV">사망여우TV</a><span class="accessible-description" id="description-id-610521"> - 채널</span></h3><div class="yt-lockup-meta"><ul class="yt-lockup-meta-info"><li>동영상 60개</li></ul></div><div class="yt-lockup-description yt-ui-ellipsis yt-ui-ellipsis-2" dir="ltr">본격 비양심 업체 및 제품 리뷰 &amp; 이슈 제보 메일 : samangfox@gmail.com 인스타그램과 페이스북으로도 제보를 받고 있습니다.</div><div class="yt-lockup-badges"><ul class="yt-badge-list"><li class="yt-badge-item"><span class="yt-badge">채널</span></li></ul> <span class="yt-uix-button-subscription-container"><button aria-busy="false" aria-live="polite" class="yt-uix-button yt-uix-button-size-default yt-uix-button-subscribe-unbranded yt-uix-button-has-icon no-icon-markup yt-uix-subscription-button yt-can-buffer yt-uix-servicelink vve-check" data-channel-external-id="UCuyN3WjEZW41qVji8TWUPeQ" data-clicktracking="itct=CFEQmysiEwjhq4G6zcvpAhXBCFgKHUlsCboyBnNlYXJjaA" data-href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;hl=ko&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26hl%3Dko%26next%3D%252Fchannel%252FUCuyN3WjEZW41qVji8TWUPeQ%26app%3Ddesktop%26feature%3Dsubscribe%26continue_action%%253D" data-params="EgIIDRgA" data-servicelink="CFEQmysiEwjhq4G6zcvpAhXBCFgKHUlsCboyBnNlYXJjaA" data-style-type="unbranded" data-unsubscribe-params="CgIIDRgA" data-visibility-tracking="CFEQmysiEwjhq4G6zcvpAhXBCFgKHUlsCboyBnNlYXJjaA" onclick=";return false;" type="button"><span class="yt-uix-button-content"><span aria-label="구독" class="subscribe-label">구독</span><span aria-label="구독 취소" class="subscribed-label">구독중</span><span aria-label="구독 취소" class="unsubscribe-label">구독 취소</span></span></button></span> </div></div></div></li>
# ...
#  위치:
#    </span>
#    한국
#  </span><span class="yt-uix-button-arrow yt-sprite"></span></button>
#  </li>
#  <li>
#  <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default" data-button-action="yt.www.picker.load" data-button-menu-id="arrow-display" data-button-toggle="true" data-picker-key="safetymode" data-picker-position="footer" id="yt-picker-safetymode-button" onclick=";return false;" type="button"><span class="yt-uix-button-content"> <span class="yt-picker-button-label">
#  제한 모드:
#    </span>
#  사용 안함
#  </span><span class="yt-uix-button-arrow yt-sprite"></span></button>
#  </li>
#  </ul>
#  <a class="yt-uix-button footer-history yt-uix-sessionlink yt-uix-button-default yt-uix-button-size-default yt-uix-button-has-icon" data-sessionlink="ei=UvDJXpfEAuuulQSauaz4Bg" href="/feed/history"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-footer-history yt-sprite"></span></span><span class="yt-uix-button-content">시청 기록</span></a> <button class="yt-uix-button yt-uix-button-size-default yt-uix-button-default yt-uix-button-has-icon yt-uix-button-reverse yt-google-help-link inq-no-click" data-feedback-product-id="59" data-ghelp-anchor="google-help" data-ghelp-tracking-param="" data-load-chat-support="true" id="google-help" onclick=";return false;" type="button"><span class="yt-uix-button-icon-wrapper"><span class="yt-uix-button-icon yt-uix-button-icon-questionmark yt-sprite"></span></span><span class="yt-uix-button-content">도움말
#  </span></button>
#  <div class="yt-picker" id="yt-picker-language-footer" style="display: none">
#  <p class="yt-spinner">
#  <span class="yt-spinner-img yt-sprite" title="로드 중 아이콘"></span>
#  <span class="yt-spinner-message">
#  로드 중...
#      </span>
#  </p>
#  </div>
#  <div class="yt-picker" id="yt-picker-country-footer" style="display: none">
#  <p class="yt-spinner">
#  <span class="yt-spinner-img yt-sprite" title="로드 중 아이콘"></span>
#  <span class="yt-spinner-message">
#  로드 중...
#      </span>
#  </p>
#  </div>
#  <div class="yt-picker" id="yt-picker-safetymode-footer" style="display: none">
#  <p class="yt-spinner">
#  <span class="yt-spinner-img yt-sprite" title="로드 중 아이콘"></span>
#  <span class="yt-spinner-message">
#  로드 중...
#      </span>
#  </p>
#  </div>
#  </div><div id="footer-links"><ul id="footer-links-primary"> <li><a href="//www.youtube.com/yt/about/ko/">정보</a></li>
#  <li><a href="//www.youtube.com/yt/press/ko/">프레스</a></li>
#  <li><a href="//www.youtube.com/yt/copyright/ko/">저작권</a></li>
#  <li><a href="//www.youtube.com/yt/creators/ko/">크리에이터</a></li>
#  <li><a href="//www.youtube.com/yt/advertise/ko/">광고</a></li>
#  <li><a href="//www.youtube.com/yt/dev/ko/">개발자</a></li>
#  </ul><ul id="footer-links-secondary"> <li><a href="/t/terms">이용약관</a></li>
#  <li><a href="https://www.google.co.kr/intl/ko/policies/privacy/">개인정보 보호</a></li>
#  <li><a href="//www.youtube.com/yt/policyandsafety/ko/">
#  정책 및 안전
#    </a></li>
#  <li><a class="reportbug" href="//support.google.com/youtube/?hl=ko" onclick="return yt.www.feedback.start(59);">의견 보내기</a></li>
#  <li>
#  <a href="/testtube">새로운 기능 테스트하기</a>
#  </li>
#  <li></li>
#  </ul></div></div></div>
#  <div class="yt-dialog hid" id="feed-privacy-lb">
#  <div class="yt-dialog-base">
#  <span class="yt-dialog-align"></span>
#  <div class="yt-dialog-fg" role="dialog">
#  <div class="yt-dialog-fg-content">
#  <div class="yt-dialog-loading">
#  <div class="yt-dialog-waiting-content">
#  <p class="yt-spinner">
#  <span class="yt-spinner-img yt-sprite" title="로드 중 아이콘"></span>
#  <span class="yt-spinner-message">
#  로드 중...
#      </span>
#  </p>
#  </div>
#  </div>
#  <div class="yt-dialog-content">
#  <div id="feed-privacy-dialog">
#  </div>
#  </div>
#  <div class="yt-dialog-working">
#  <div class="yt-dialog-working-overlay"></div>
#  <div class="yt-dialog-working-bubble">
#  <div class="yt-dialog-waiting-content">
#  <p class="yt-spinner">
#  <span class="yt-spinner-img yt-sprite" title="로드 중 아이콘"></span>
#  <span class="yt-spinner-message">
#          진행 중...
#      </span>
#  </p>
#  </div>
#  </div>
#  </div>
#  </div>
#  <div class="yt-dialog-focus-trap" tabindex="0"></div>
#  </div>
#  </div>
#  </div>
#  <div class="hid" id="hidden-component-template-wrapper"> <div class="hid" id="shared-addto-watch-later-login">
#        나중에 볼 동영상에 추가하려면 <a class="sign-in-link" href="https://accounts.google.com/ServiceLogin?service=youtube&amp;uilel=3&amp;passive=true&amp;hl=ko&amp;continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26hl%3Dko%26next%3D%252Fresults%253Fsearch_query%253D%2525EC%252599%252580%2525EB%252594%252594%2525EC%2525A6%252588%26app%3Ddesktop%26feature%3Dplaylist">로그인</a>하세요.
#
#      </div>
#  <div class="yt-ui-menu-content" id="yt-uix-videoactionmenu-menu"> <div class="hide-on-create-pl-panel">
#  <h3>
#  추가
#      </h3>
#  </div>
#  <div class="add-to-widget">
#  <p class="yt-spinner">
#  <span class="yt-spinner-img yt-sprite" title="로드 중 아이콘"></span>
#  <span class="yt-spinner-message">
#          재생목록 로드 중...
#      </span>
#  </p>
#  </div>
#  </div></div> <script>var ytspf = ytspf || {};ytspf.enabled = true;ytspf.config = {'reload-identifier': 'spfreload'};ytspf.config['request-headers'] = {'X-YouTube-Ad-Signals': {toString: function() {return (window['yt'] && yt['ads_'] && yt.ads_['signals_'] &&yt.ads_.signals_['getAdSignalsString']) ?yt.ads_.signals_.getAdSignalsString() :'';}},'X-YouTube-Identity-Token': null};ytspf.config['experimental-request-headers'] = ytspf.config['request-headers'];ytspf.config['cache-max'] = 50;ytspf.config['navigate-limit'] = 50;ytspf.config['navigate-lifetime'] = 64800000;</script>
#  <script name="spf/spf" src="/yts/jsbin/spf-vflKdaZ7t/spf.js" type="text/javascript"></script>
#  <script name="www/base" src="/yts/jsbin/www-en_US-vflWQT_KB/base.js"></script>
#  <script>spf.script.path({'www/': '/yts/jsbin/www-en_US-vflWQT_KB/'});var ytdepmap = {"www/base": null, "www/common": "www/base", "www/angular_base": "www/common", "www/channels_accountupload": "www/common", "www/channels": "www/common", "www/dashboard": "www/common", "www/downloadreports": "www/common", "www/experiments": "www/common", "www/feed": "www/common", "www/legomap": "www/common", "www/promo_join_network": "www/common", "www/results_harlemshake": "www/common", "www/results": "www/common", "www/results_starwars": "www/common", "www/subscriptionmanager": "www/common", "www/unlimited": "www/common", "www/watch": "www/common", "www/ypc_bootstrap": "www/common", "www/ypc_core": "www/common", "www/channels_edit": "www/channels", "www/live_dashboard": "www/angular_base", "www/videomanager": "www/angular_base", "www/watch_autoplayrenderer": "www/watch", "www/watch_edit": "www/watch", "www/watch_editor": "www/watch", "www/watch_promos": "www/watch", "www/watch_speedyg": "www/watch", "www/watch_transcript": "www/watch", "www/watch_videoshelf": "www/watch", "www/ct_advancedsearch": "www/videomanager", "www/my_videos": "www/videomanager", "www/$weak$": ["www/angular_base", "www/base", "www/channels_accountupload", "www/channels_edit", "www/channels", "www/common", "www/ct_advancedsearch", "www/dashboard", "www/downloadreports", "www/experiments", "www/feed", "www/legomap", "www/live_dashboard", "www/my_videos", "www/promo_join_network", "www/results_harlemshake", "www/results", "www/results_starwars", "www/subscriptionmanager", "www/unlimited", "www/videomanager", "www/watch_autoplayrenderer", "www/watch_edit", "www/watch_editor", "www/watch", "www/watch_promos", "www/watch_speedyg", "www/watch_transcript", "www/watch_videoshelf", "www/ypc_bootstrap", "www/ypc_core"]};spf.script.declare(ytdepmap);</script> <script name="fetch-polyfill/fetch-polyfill" src="/yts/jsbin/fetch-polyfill-vflXSfNZ5/fetch-polyfill.js" type="text/javascript"></script>
#  <script>if (window.ytcsi) {window.ytcsi.tick("je", null, '');}</script>
#  <script>
#          yt.setConfig({
#        'JS_PAGE_MODULES': [
#          'www/results',
#          'www/ypc_bootstrap',
#          'www/feed',
#          ''
#        ],
#
#        'TIMING_REPORT_ON_UNLOAD': true
#      });
#
#
#        yt.setConfig({
#      'GUIDED_HELP_LOCALE': "ko_KR",
#      'GUIDED_HELP_ENVIRONMENT': "prod"
#    });
#
#    </script>
#  <script>yt.setConfig({INNERTUBE_CONTEXT_CLIENT_NAME: 1,GAPI_HINT_PARAMS: "m;\/_\/scs\/abc-static\/_\/js\/k=gapi.gapi.en.jw7XZHvcak8.O\/d=1\/ct=zgms\/rs=AHpOoo-L1iz4xVj0PCdm2On38RCj6aYemA\/m=__features__",INNERTUBE_API_KEY: "AIzaSyAO_FJ2SlqU8Q4STEHLGCilw_Y9_11qcW8",INNERTUBE_API_VERSION: "v1",INNERTUBE_CONTEXT_CLIENT_VERSION: "1.20200521.03.02",'VISITOR_DATA': "CgtzYlJzWjRyRlNrMCjS4Kf2BQ%3D%3D",'DELEGATED_SESSION_ID': null,'GAPI_HOST': "https:\/\/apis.google.com",'GAPI_LOCALE': "ko_KR",'INNERTUBE_CONTEXT_HL': "ko",'INNERTUBE_CONTEXT_GL': "KR",'XHR_APIARY_HOST': "youtubei.youtube.com"});yt.setConfig({'PAGE_NAME': "results",'LOGGED_IN': false,'SESSION_INDEX': null,'VALID_SESSION_TEMPDATA_DOMAINS': ["www.youtube.com","gaming.youtube.com"],'PARENT_TRACKING_PARAMS': "",'FORMATS_FILE_SIZE_JS': ["%sB","%sKB","%sMB","%sGB","%sTB"],'ONE_PICK_URL': "",'GOOGLEPLUS_HOST': "https:\/\/plus.google.com",'PAGEFRAME_JS': "\/yts\/jsbin\/www-pageframe-vfl4Ntk3g\/www-pageframe.js",'GAPI_LOADER_URL': "\/yts\/jsbin\/www-gapi-loader-vflTAgkAL\/www-gapi-loader.js",'JS_COMMON_MODULE': "\/yts\/jsbin\/www-en_US-vflWQT_KB\/common.js",'PAGE_FRAME_DELAYLOADED_CSS': "\/yts\/cssbin\/www-pageframedelayloaded-vfl0WpMvu.css",'EXPERIMENT_FLAGS': {"polymer_verifiy_app_state":true,"service_worker_push_watch_page_prompt":true,"consent_url_override":"","enable_device_forwarding_from_xhr_client":true,"log_window_onerror_fraction":0.1,"service_worker_push_prompt_delay_microseconds":3888000000000,"pass_biscotti_id_in_header_ajax":true,"polymer_bad_build_labels":true,"disable_legacy_desktop_remote_queue_watch":true,"custom_csi_timeline_use_gel":true,"desktop_polymer_video_masthead_session_tempdata_ttl":30,"watch_next_pause_autoplay_lact_sec":4500,"html5_experiment_id_label":0,"web_deprecate_service_ajax_map_dependency":true,"web_screen_manager_use_default_client":true,"web_op_signal_type_blacklist":[],"web_client_counter_random_seed":true,"use_sonic_js_library_for_v4_support":true,"enable_ve_tracker_key":true,"desktop_action_companion_wta_support":true,"warm_load_nav_start_web":true,"disable_simple_mixed_direction_formatted_strings":true,"suppress_gen_204":true,"csi_on_gel":true,"service_worker_push_logged_out_prompt_watches":-1,"live_chat_client_url":true,"autoescape_tempdata_url":true,"gfeedback_for_signed_out_users_enabled":true,"autoplay_pause_by_lact_sampling_fraction":0.0,"service_worker_push_home_page_prompt":true,"desktop_videowall_companion_wta_support":true,"enable_device_forwarding_from_polymer_network_manager":true,"enable_premium_voluntary_pause":true,"desktop_sparkles_light_cta_button":true,"web_use_beacon_api_for_ad_click_server_pings":true,"disable_thumbnail_preloading":true,"cancel_pending_navs":true,"web_logging_max_batch":150,"use_typescript_transport":true,"web_screen_associated_all_layers":true,"mdx_enable_privacy_disclosure_ui":true,"overwrite_polyfill_on_logging_lib_loaded":true,"web_post_search":true,"enable_mixed_direction_formatted_strings":true,"service_worker_enabled":true,"ignore_empty_xhr":true,"service_worker_push_prompt_cap":-1,"should_clear_video_data_on_player_cued_unstarted":true,"web_network_combined_catch":true,"live_chat_increased_min_height":true,"botguard_periodic_refresh":true,"desktop_pyv_on_watch_missing_params":true,"desktop_shopping_companion_wta_support":true,"enable_read_more_format_decoration":true,"web_system_health_fraction":0.01,"botguard_async_snapshot_timeout_ms":2000,"network_polling_interval":30000,"web_op_endpoint_blacklist":[],"enable_watch_next_pause_autoplay_lact":true,"app_settings_snapshot_min_time_between_snapshots_hours":24,"desktop_image_companion_wta_support":true,"prefetch_comments_ms_after_video":0,"retry_web_logging_batches":true,"web_gel_debounce_ms":10000,"web_yt_config_context":true,"delay_gel_until_config_ready":true,"desktop_notification_set_title_bar":true,"enable_ypc_spinners":true,"desktop_pyv_on_watch_override_lact":true,"web_op_continuation_type_blacklist":[],"use_watch_fragments2":true,"web_al ...
#      'GUIDED_HELP_LOCALE': "ko_KR",
#      'GUIDED_HELP_ENVIRONMENT': "prod"
#    });
#  yt.setConfig('SPF_SEARCH_BOX', true);yt.setMsg({'ADDTO_CREATE_NEW_PLAYLIST': "새 재생목록 만들기\n",'ADDTO_CREATE_PLAYLIST_DYNAMIC_TITLE': "  $dynamic_title_placeholder(새로 만들기)\n",'ADDTO_WATCH_LATER': "Watch later",'ADDTO_WATCH_LATER_ADDED': "추가됨",'ADDTO_WATCH_LATER_ERROR': "오류",'ADDTO_WATCH_QUEUE': "Watch Queue",'ADDTO_WATCH_QUEUE_ADDED': "추가됨",'ADDTO_WATCH_QUEUE_ERROR': "오류",'ADDTO_TV_QUEUE': "Queue",'MASTHEAD_NOTIFICATIONS_LABEL': {"case0": "\uc77d\uc9c0 \uc54a\uc740 \uc54c\ub9bc \uc5c6\uc74c", "case1": "\uc77d\uc9c0 \uc54a\uc740 \uc54c\ub9bc 1\uac1c", "other": "\uc77d\uc9c0 \uc54a\uc740 \uc54c\ub9bc #\uac1c"},'MASTHEAD_NOTIFICATIONS_COUNT_99PLUS': "99+",'MDX_AUTOPLAY_OFF': '자동재생 해제됨','MDX_AUTOPLAY_ON': '자동재생 사용 중'});  yt.setConfig('FEED_PRIVACY_CSS_URL', "\/yts\/cssbin\/www-feedprivacydialog-vfl3mbjRm.css");
#    yt.setConfig('FEED_PRIVACY_LIGHTBOX_ENABLED', true);
#  yt.setConfig({'SBOX_JS_URL': "\/yts\/jsbin\/www-searchbox-vflLKKpaF\/www-searchbox.js",'SBOX_SETTINGS': {"PQ":"와디즈","REQUEST_LANGUAGE":"ko","REQUEST_DOMAIN":"kr","HAS_ON_SCREEN_KEYBOARD":true},'SBOX_LABELS': {"SUGGESTION_DISMISS_LABEL":"삭제","SUGGESTION_DISMISSED_LABEL":"추천 검색어 삭제됨"}});  yt.setConfig({
#      'YPC_LOADER_JS': "\/yts\/jsbin\/www-ypc-vfl_kjlM0\/www-ypc.js",
#      'YPC_LOADER_CSS': "\/yts\/cssbin\/www-ypc-vflVd_jtI.css",
#      'YPC_SIGNIN_URL': "https:\/\/accounts.google.com\/ServiceLogin?service=youtube\u0026uilel=3\u0026passive=true\u0026hl=ko\u0026continue=https%3A%2F%2Fwww.youtube.com%2Fsignin%3Faction_handle_signin%3Dtrue%26hl%3Dko%26next%3D%252F%26app%3Ddesktop",
#      'DBLCLK_ADVERTISER_ID': "2542116",
#      'DBLCLK_YPC_ACTIVITY_GROUP': "youtu444",
#      'SUBSCRIPTION_URL': "\/subscription_ajax",
#      'YPC_SWITCH_URL': "\/signin?action_handle_signin=true\u0026next=%2F\u0026feature=purchases\u0026skip_identity_prompt=True",
#      'YPC_GB_LANGUAGE': "ko_KR",
#      'YPC_MB_URL': "https:\/\/payments.youtube.com\/payments\/v4\/js\/integrator.js?ss=md",
#      'YPC_TRANSACTION_URL': "\/transaction_handler",
#      'YPC_SUBSCRIPTION_URL': "\/ypc_subscription_ajax",
#      'YPC_POST_PURCHASE_URL': "\/ypc_post_purchase_ajax",
#      'YTR_FAMILY_CREATION_URL': "https:\/\/families.google.com\/webcreation?usegapi=1",
#      'YTO_GTM_DATA': {'event': 'purchased', 'purchaseStatus': 'success'},
#      'YTO_GTM_1_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '1'},
#      'YTO_GTM_2_BUTTON_CLICK_DATA': {'event': 'landingButtonClick', 'buttonPosition': '2'}
#    });
#    yt.setMsg({
#      'YPC_OFFER_OVERLAY': "  \n",
#      'YPC_UNSUBSCRIBE_OVERLAY': "  \n"
#    });
#    yt.setConfig('GOOGLE_HELP_CONTEXT', "search_results");
#  ytcsi.info('st', 433);ytcfg.set({"CSI_SERVICE_NAME":"youtube","TIMING_INFO":{"c":"WEB","cver":"1.20200521.03.02","yt_li":"0","yt_lt":"cold","yt_ad":"1","GetSearch_rid":"0xaac272cceea92aa7"}});;ytcfg.set({"CSI_VIEWPORT":true,"TIMING_ACTION":"results","TIMING_AFT_KEYS":["ol"],"TIMING_WAIT":["ol","cpt"]});;  yt.setConfig({
#        'XSRF_TOKEN': "",
#        'XSRF_FIELD_NAME': "session_token",
#
#        'XSRF_REDIRECT_TOKEN': "DfNI_Fuk0AV8tXYPHyWBYlWw9Uh8MTU5MDM3ODk2MkAxNTkwMjkyNTYy"  });
#  yt.setConfig('ID_TOKEN', null);yt.setConfig('INNERTUBE_CONTEXT', {"client":{"hl":"ko","gl":"KR","visitorData":"CgtzYlJzWjRyRlNrMCjS4Kf2BQ%3D%3D","userAgent":"python-requests/2.23.0,gzip(gfe)","clientName":"WEB","clientVersion":"1.20200521.03.02"},"request":{"sessionId":"6830254545214913424"}});window.ytcfg.set('SERVICE_WORKER_KILLSWITCH', false);  yt.setConfig('THUMB_DELAY_LOAD_BUFFER', 0);
#  if (window.ytcsi) {window.ytcsi.tick("jl", null, '');}</script>
#  </body>]

# %%
ytd-video-renderer.style-scope:nth-child(1) > div:nth-child(1) > div:nth-child(2) > div:nth-child(1) > ytd-video-meta-block:nth-child(2) > div:nth-child(1) > div:nth-child(1) > ytd-channel-name:nth-child(1) > div:nth-child(1) > div:nth-child(1) > yt-formatted-string:nth-child(1) > a:nth-child(1)
